# %%
# !pip install PySerial
# Out:
# Collecting PySerial
#   Using cached pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Installing collected packages: PySerial
# Successfully installed PySerial-3.5

# %%
import serial
import cv2
import re


cap = cv2.VideoCapture(0) 

#cap = cv2.VideoCapture("http://192.168.43.1:8080/video"
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_BUFFERSIZE, 1)

count=0
pattern = r'[0-9]'
ser = serial.Serial("COM7", 9600, timeout = 11)
def retrieveData():
    #ser.write(b'1')
    data = ser.readline()
    return data

while 1 :
    data=retrieveData()
    data=data.rstrip()
    if data.isdigit():
        if int(data) < 20:
            print(data)
            count=count+1
            return_value, image = cap.read()
            cv2.imwrite('Images/'+str(count)+'.png', image)
            print("capture")
        else:
            return_value, image = cap.read()
            cv2.imwrite('Images1/'+"image"+'.png', image)
# Out:
# b'15'
# capture
# b'15'
# capture
# b'15'
# capture
# b'16'
# capture
# b'17'
# capture
# b'18'
# capture
# b'17'
# capture
# b'17'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'16'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'17'
# capture
# b'16'
# capture
# b'17'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'16'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'17'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'19'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'17'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'16'
# capture
# b'16'
# capture
# b'16'
# capture
# b'18'
# capture
# b'17'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'18'
# capture
# b'14'
# capture
# b'14'
# capture
# b'15'
# capture
# b'15'
# capture
# b'16'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'16'
# capture
# b'16'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'16'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'18'
# capture
# b'18'
# capture
# b'17'
# capture
# b'18'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'18'
# capture
# b'18'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'17'
# capture
# b'16'
# capture
# b'16'
# capture
# b'17'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
# b'19'
# capture
